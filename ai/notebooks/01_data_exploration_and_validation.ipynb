# %% [markdown]
# # SmartEnergyMonitor - Day 5: ML Data Preparation & Validation
#
# This notebook demonstrates the loading, cleaning, feature engineering, and baseline benchmarking of the energy monitoring dataset.

# %%
import sys
from pathlib import Path
import pandas as pd

# Add src to path
src_dir = Path.cwd().parent / 'src'
sys.path.insert(0, str(src_dir))

from load_data import load_raw_data_from_db
from clean_data import clean_energy_data, check_data_quality, print_quality_report
from feature_engineering import run_pipeline

# %%
# Run the full end-to-end preprocessing pipeline
ml_df, train_df, test_df = run_pipeline()

# %%
# Display sample processed records
ml_df.head(10)
